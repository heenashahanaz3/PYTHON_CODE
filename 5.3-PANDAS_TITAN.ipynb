# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("C:\\Users\\Dell\\Downloads\\Titan.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_39440\964094849.py in <module>
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.shape
# Out:
# (418, 12)

# %%
df.ndim
# Out:
# 2

# %%
df[10:20]
# Out:
#     PassengerId  Survived  Pclass  \
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 10                                   Ilieff, Mr. Ylio    male   NaN      0
# 11                         Jones, Mr. Charles Cresson    male  46.0      0
# 12      Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 13                               Howard, Mr. Benjamin    male  63.0      1
# 14  Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 15      del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# ...

# %%
df[30:60:2]
# Out:
#     PassengerId  Survived  Pclass  \
# 30          922         0       2
# 32          924         1       3
# 34          926         0       1
# 36          928         1       3
# 38          930         0       3
# 40          932         0       3
# 42          934         0       3
# 44          936         1       1
# 46          938         0       1
# 48          940         1       1
# 50          942         0       1
# 52          944         1       2
# 54          946         0       2
# 56          948         0       3
# 58          950         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 30                      Louch, Mr. Charles Alexander    male  50.0      1
# 32          Dean, Mrs. Bertram (Eva Georgetta Light)  female  33.0      1
# 34                          Mock, Mr. Philipp Edmund    male  30.0      1
# 36                               Roth, Miss. Sarah A  female   NaN      0
# ...

# %%
df['Fare']
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
df[['Fare','Sex']]
# Out:
#          Fare     Sex
# 0      7.8292    male
# 1      7.0000  female
# 2      9.6875    male
# 3      8.6625    male
# 4     12.2875  female
# ..        ...     ...
# 413    8.0500    male
# 414  108.9000  female
# 415    7.2500    male
# 416    8.0500    male
# 417   22.3583    male
#
# [418 rows x 2 columns]

# %%
df[['Sex','Ticket']][40:80:2]
# Out:
#        Sex              Ticket
# 40    male              349256
# 42    male  SOTON/O.Q. 3101263
# 44  female               11753
# 46    male            PC 17594
# 48  female               11813
# 50    male               13695
# 52  female               29105
# 54    male         SC/A.3 2861
# 56    male              349230
# 58    male              386525
# 60    male              349232
# 62    male              347090
# 64    male            PC 17608
# 66  female              330963
# 68    male                2543
# 70  female              382653
# 72  female             3101297
# 74  female              113503
# 76    male              359306
# 78    male              248744

# %%
for rec in df.iterrows():
    print(rec)
# Out:
# (0, PassengerId                 892
# Survived                      0
# Pclass                        3
# Name           Kelly, Mr. James
# Sex                        male
# Age                        34.5
# SibSp                         0
# Parch                         0
# Ticket                   330911
# Fare                     7.8292
# Cabin                       NaN
# Embarked                      Q
# Name: 0, dtype: object)
# (1, PassengerId                                 893
# Survived                                      1
# Pclass                                        3
# Name           Wilkes, Mrs. James (Ellen Needs)
# Sex                                      female
# Age                                        47.0
# SibSp                                         1
# Parch                                         0
# Ticket                                   363272
# Fare                                        7.0
# Cabin                                       NaN
# ...

# %%
df.loc[46]
# Out:
# PassengerId                         938
# Survived                              0
# Pclass                                1
# Name           Chevre, Mr. Paul Romaine
# Sex                                male
# Age                                45.0
# SibSp                                 0
# Parch                                 0
# Ticket                         PC 17594
# Fare                               29.7
# Cabin                                A9
# Embarked                              C
# Name: 46, dtype: object

# %%
df.loc[66,['Ticket']]
# Out:
# Ticket    330963
# Name: 66, dtype: object

# %%
df.loc[80:90]
# Out:
#     PassengerId  Survived  Pclass  \
# 80          972         0       3
# 81          973         0       1
# 82          974         0       1
# 83          975         0       3
# 84          976         0       2
# 85          977         0       3
# 86          978         1       3
# 87          979         1       3
# 88          980         1       3
# 89          981         0       2
# 90          982         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 80                               Boulos, Master. Akar    male   6.0      1
# 81                                 Straus, Mr. Isidor    male  67.0      1
# 82                             Case, Mr. Howard Brown    male  49.0      0
# 83                               Demetri, Mr. Marinko    male   NaN      0
# 84                              Lamb, Mr. John Joseph    male   NaN      0
# 85                                 Khalil, Mr. Betros    male   NaN      1
# ...

# %%
df.loc[20:30,['Ticket','Sex']]
# Out:
#         Ticket     Sex
# 20    PC 17603    male
# 21     C 17368    male
# 22    PC 17598  female
# 23    PC 17597    male
# 24    PC 17608  female
# 25   A/5. 3337    male
# 26      113509  female
# 27        2698    male
# 28      113054    male
# 29        2662    male
# 30  SC/AH 3085    male

# %%
df.loc[40:50,'PassengerId':'Parch']
# Out:
#     PassengerId  Survived  Pclass  \
# 40          932         0       3
# 41          933         0       1
# 42          934         0       3
# 43          935         1       2
# 44          936         1       1
# 45          937         0       3
# 46          938         0       1
# 47          939         0       3
# 48          940         1       1
# 49          941         1       3
# 50          942         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 40                                  Karun, Mr. Franz    male  39.0      0
# 41                       Franklin, Mr. Thomas Parham    male   NaN      0
# 42                             Goldsmith, Mr. Nathan    male  41.0      0
# 43             Corbett, Mrs. Walter H (Irene Colvin)  female  30.0      0
# 44  Kimball, Mrs. Edwin Nelson Jr (Gertrude Parsons)  female  45.0      1
# 45                   Peltomaki, Mr. Nikolai Johannes    male  25.0      0
# ...

# %%
df.iloc[100:120]
# Out:
#      PassengerId  Survived  Pclass  \
# 100          992         1       1
# 101          993         0       2
# 102          994         0       3
# 103          995         0       3
# 104          996         1       3
# 105          997         0       3
# 106          998         0       3
# 107          999         0       3
# 108         1000         0       3
# 109         1001         0       2
# 110         1002         0       2
# 111         1003         1       3
# 112         1004         1       1
# 113         1005         1       3
# 114         1006         1       1
# 115         1007         0       3
# 116         1008         0       3
# 117         1009         1       3
# 118         1010         0       1
# 119         1011         1       2
#
#                                                   Name     Sex   Age  SibSp  \
# 100  Stengel, Mrs. Charles Emil Henry (Annie May Mo...  female  43.0      1
# ...

# %%
df.iloc[100,2]
# Out:
# 1

# %%
df.iloc[400,3]
# Out:
# 'Bonnell, Miss. Caroline'

# %%
df.iloc[0:20,0:4]
# Out:
#     PassengerId  Survived  Pclass  \
# 0           892         0       3
# 1           893         1       3
# 2           894         0       2
# 3           895         0       3
# 4           896         1       3
# 5           897         0       3
# 6           898         1       3
# 7           899         0       2
# 8           900         1       3
# 9           901         0       3
# 10          902         0       3
# 11          903         0       1
# 12          904         1       1
# 13          905         0       2
# 14          906         1       1
# 15          907         1       2
# 16          908         0       2
# 17          909         0       3
# 18          910         1       3
# 19          911         1       3
#
#                                                  Name
# 0                                    Kelly, Mr. James
# 1                    Wilkes, Mrs. James (Ellen Needs)
# 2                           Myles, Mr. Thomas Francis
# ...

# %%
df.iloc[20:40,2]
# Out:
# 20    1
# 21    3
# 22    1
# 23    1
# 24    1
# 25    3
# 26    1
# 27    3
# 28    1
# 29    3
# 30    2
# 31    2
# 32    3
# 33    3
# 34    1
# 35    3
# 36    3
# 37    3
# 38    3
# 39    3
# Name: Pclass, dtype: int64

# %%
df.iloc[[20,40,60,80,100]]
# Out:
#      PassengerId  Survived  Pclass  \
# 20           912         0       1
# 40           932         0       3
# 60           952         0       3
# 80           972         0       3
# 100          992         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 20                              Rothschild, Mr. Martin    male  55.0      1
# 40                                    Karun, Mr. Franz    male  39.0      0
# 60                                     Dika, Mr. Mirko    male  17.0      0
# 80                                Boulos, Master. Akar    male   6.0      1
# 100  Stengel, Mrs. Charles Emil Henry (Annie May Mo...  female  43.0      1
#
#      Parch    Ticket     Fare Cabin Embarked
# 20       0  PC 17603  59.4000   NaN        C
# 40       1    349256  13.4167   NaN        C
# 60       0    349232   7.8958   NaN        S
# 80       1      2678  15.2458   NaN        C
# 100      0     11778  55.4417  C116        C

# %%
df.loc[:,['Parch']]
# Out:
#      Parch
# 0        0
# 1        0
# 2        0
# 3        0
# 4        1
# ..     ...
# 413      0
# 414      0
# 415      0
# 416      0
# 417      1
#
# [418 rows x 1 columns]

# %%
df.iloc[1:10,[1,4,6]]
# Out:
#    Survived     Sex  SibSp
# 1         1  female      1
# 2         0    male      0
# 3         0    male      0
# 4         1  female      1
# 5         0    male      0
# 6         1  female      0
# 7         0    male      1
# 8         1  female      0
# 9         0    male      2

# %% [markdown]
# # #### Sorting the data frame

# %%
### ascending order
df.sort_values('Parch')
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 266         1158         0       1
# 265         1157         0       3
# 264         1156         0       2
# 261         1153         0       3
# ..           ...       ...     ...
# 132         1024         1       3
# 174         1066         0       3
# 139         1031         0       3
# 365         1257         1       3
# 342         1234         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 266       Chisholm, Mr. Roderick Robert Crispin    male   NaN      0      0
# 265                       Lyntakoff, Mr. Stanko    male   NaN      0      0
# 264      Portaluppi, Mr. Emilio Ilario Giuseppe    male  30.0      0      0
# 261               Nilsson, Mr. August Ferdinand    male  21.0      0      0
# ..                                          ...     ...   ...    ...    ...
# ...

# %%
df.sort_values('Parch',ascending=False)
# Out:
#      PassengerId  Survived  Pclass  \
# 365         1257         1       3
# 342         1234         0       3
# 139         1031         0       3
# 174         1066         0       3
# 132         1024         1       3
# ..           ...       ...     ...
# 145         1037         0       3
# 144         1036         0       1
# 143         1035         0       2
# 141         1033         1       1
# 209         1101         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 365                     Sage, Mrs. John (Annie Bullen)  female   NaN      1
# 342                              Sage, Mr. John George    male   NaN      1
# 139                     Goodwin, Mr. Charles Frederick    male  40.0      1
# 174         Asplund, Mr. Carl Oscar Vilhelm Gustafsson    male  40.0      1
# 132                      Lefebre, Mrs. Frank (Frances)  female   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.sort_values(['Name','Fare'])
# Out:
#      PassengerId  Survived  Pclass  \
# 392         1284         0       3
# 345         1237         1       3
# 57           949         0       3
# 251         1143         0       3
# 8            900         1       3
# ..           ...       ...     ...
# 336         1228         0       2
# 260         1152         0       3
# 15           907         1       2
# 344         1236         0       3
# 192         1084         0       3
#
#                                               Name     Sex   Age  SibSp  \
# 392                  Abbott, Master. Eugene Joseph    male  13.0      0
# 345                    Abelseth, Miss. Karen Marie  female  16.0      0
# 57                   Abelseth, Mr. Olaus Jorgensen    male  25.0      0
# 251       Abrahamsson, Mr. Abraham August Johannes    male  20.0      0
# 8        Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# ..                                             ...     ...   ...    ...
# ...

# %%
df.drop(columns='Embarked')
### to remove permanently use inplace= true
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 413    False
# 414    False
# 415    False
# 416    False
# 417    False
# Length: 418, dtype: bool

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# # ### Null values

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.isnull().sum().any()
# Out:
# True

# %%
df.ffill()

#data
#0
#null
#2

#after ffill
#0
#2
#2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.bfill()

# data before bfill
#0
#null
#2

# data after bfill
#0
#0
#2
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.fillna(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...
