# %%
Null values

    -> How null values are generated
    
    -> How to find null values
    
    -> how to fill null values

# %%
What is null values?

Null values are nothing but empty 

-> In pandas DataFrame null values are in the form of NaN

# %%
-> How null values are generate

    -> Type error null 
    
    -> filling the form (manditory and non manditory fields)
    
    -> system generate null value if any code error
    
    -> User creating null values
    
        -> special chars
        
        -> extreme values
        
    -> .....

# %%
#seaborn

# %%
import pandas as pd
import seaborn as sns

df = sns.load_dataset("mpg")
df
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df.shape
# Out:
# (398, 9)

# %%
df.head(5)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %%
df.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  398.000000  398.000000    398.000000  392.000000   398.000000
# mean    23.514573    5.454774    193.425879  104.469388  2970.424623
# std      7.815984    1.701004    104.269838   38.491160   846.841774
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.500000    4.000000    104.250000   75.000000  2223.750000
# 50%     23.000000    4.000000    148.500000   93.500000  2803.500000
# 75%     29.000000    8.000000    262.000000  126.000000  3608.000000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    398.000000  398.000000
# mean      15.568090   76.010050
# std        2.757689    3.697627
# min        8.000000   70.000000
# 25%       13.825000   73.000000
# 50%       15.500000   76.000000
# 75%       17.175000   79.000000
# max       24.800000   82.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df['mpg'] = df['mpg'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    int32
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(3), int32(1), int64(3), object(2)
# memory usage: 26.6+ KB

# %%
-> Finding the null values

    -> isnull()
    
    -> isnull().sum()
    
    -> isnull().any()
    
    -> isnull().sum().sum()
    
    -> isnll().any().sum()
# Out:
#   File "<ipython-input-75-4577a42b6515>", line 1
#     -> Finding the null values
#      ^
# SyntaxError: invalid syntax

# %%
# each element we are going to have null value are not
df.isnull()
# Out:
#        mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False      False         False       False   False         False
# 1    False      False         False       False   False         False
# 2    False      False         False       False   False         False
# 3    False      False         False       False   False         False
# 4    False      False         False       False   False         False
# ..     ...        ...           ...         ...     ...           ...
# 393  False      False         False       False   False         False
# 394  False      False         False       False   False         False
# 395  False      False         False       False   False         False
# 396  False      False         False       False   False         False
# 397  False      False         False       False   False         False
#
#      model_year  origin   name
# 0         False   False  False
# 1         False   False  False
# ...

# %%
# each column null values is there nor not
df.isnull().any()
# Out:
# mpg             False
# cylinders       False
# displacement    False
# horsepower       True
# weight          False
# acceleration    False
# model_year      False
# origin          False
# name            False
# dtype: bool

# %%
# in data frame null values there or not
df.isnull().any().any()
# Out:
# True

# %%
# each column how many null values are there
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
# total number of null values in the dataframe
df.isnull().sum().sum()
# Out:
# 6

# %%
# now i want a particular to know null values count
df['cylinders'].isnull().sum()
# Out:
# 0

# %%
# now i want a particular to know null values counts as I choose
df[['cylinders','horsepower']].isnull().sum()
# Out:
# cylinders     0
# horsepower    6
# dtype: int64

# %%
How to fill values 

    -> forwardfill => sequential repeated values
    
    1
    2
    null --- 4
    4
    5
    
    -> backwardfill => sequential repeated values
    
    -> fillna => if we know what to fill
    
    -> replace => replacing the null values wi=th someother value
    
    -> mean => replacing with mean if any extreme values then use median
    
    -> median => filling null value with middle value
    
    -> mode => using relation formula r most repeated one
    
    -> random => In set of values choosing one value
    
    -> imputer methods> sklearn
    
    -> min -> minimum 
    
    -> max -> maximum value in the set of data

# %%
df.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
# default forward fill done on the bases of rows. or we can keep axis =0
df.fillna(method='ffill')
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0     18          8         307.0       130.0    3504          12.0
# 1     15          8         350.0       165.0    3693          11.5
# 2     18          8         318.0       150.0    3436          11.0
# 3     16          8         304.0       150.0    3433          12.0
# 4     17          8         302.0       140.0    3449          10.5
# ..   ...        ...           ...         ...     ...           ...
# 393   27          4         140.0        86.0    2790          15.6
# 394   44          4          97.0        52.0    2130          24.6
# 395   32          4         135.0        84.0    2295          11.6
# 396   28          4         120.0        79.0    2625          18.6
# 397   31          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# filling null values with forward fill based on column when axis =1
df.fillna(method='ffill',axis=1)
# Out:
#     mpg cylinders displacement horsepower weight acceleration model_year  \
# 0    18         8        307.0      130.0   3504         12.0         70
# 1    15         8        350.0      165.0   3693         11.5         70
# 2    18         8        318.0      150.0   3436         11.0         70
# 3    16         8        304.0      150.0   3433         12.0         70
# 4    17         8        302.0      140.0   3449         10.5         70
# ..   ..       ...          ...        ...    ...          ...        ...
# 393  27         4        140.0       86.0   2790         15.6         82
# 394  44         4         97.0       52.0   2130         24.6         82
# 395  32         4        135.0       84.0   2295         11.6         82
# 396  28         4        120.0       79.0   2625         18.6         82
# 397  31         4        119.0       82.0   2720         19.4         82
#
#      origin                       name
# 0       usa  chevrolet chevelle malibu
# ...

# %%
df.ffill()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0     18          8         307.0       130.0    3504          12.0
# 1     15          8         350.0       165.0    3693          11.5
# 2     18          8         318.0       150.0    3436          11.0
# 3     16          8         304.0       150.0    3433          12.0
# 4     17          8         302.0       140.0    3449          10.5
# ..   ...        ...           ...         ...     ...           ...
# 393   27          4         140.0        86.0    2790          15.6
# 394   44          4          97.0        52.0    2130          24.6
# 395   32          4         135.0        84.0    2295          11.6
# 396   28          4         120.0        79.0    2625          18.6
# 397   31          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# default backward fill done on the bases of rows. or we can keep axis =0
df.fillna(method='bfill')
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0     18          8         307.0       130.0    3504          12.0
# 1     15          8         350.0       165.0    3693          11.5
# 2     18          8         318.0       150.0    3436          11.0
# 3     16          8         304.0       150.0    3433          12.0
# 4     17          8         302.0       140.0    3449          10.5
# ..   ...        ...           ...         ...     ...           ...
# 393   27          4         140.0        86.0    2790          15.6
# 394   44          4          97.0        52.0    2130          24.6
# 395   32          4         135.0        84.0    2295          11.6
# 396   28          4         120.0        79.0    2625          18.6
# 397   31          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
# filling null values with backward fill based on column when axis =1
df.fillna(method='bfill',axis=1)
# Out:
#     mpg cylinders displacement horsepower weight acceleration model_year  \
# 0    18         8        307.0      130.0   3504         12.0         70
# 1    15         8        350.0      165.0   3693         11.5         70
# 2    18         8        318.0      150.0   3436         11.0         70
# 3    16         8        304.0      150.0   3433         12.0         70
# 4    17         8        302.0      140.0   3449         10.5         70
# ..   ..       ...          ...        ...    ...          ...        ...
# 393  27         4        140.0       86.0   2790         15.6         82
# 394  44         4         97.0       52.0   2130         24.6         82
# 395  32         4        135.0       84.0   2295         11.6         82
# 396  28         4        120.0       79.0   2625         18.6         82
# 397  31         4        119.0       82.0   2720         19.4         82
#
#      origin                       name
# 0       usa  chevrolet chevelle malibu
# ...

# %%
df.bfill(axis=1)
# Out:
#     mpg cylinders displacement horsepower weight acceleration model_year  \
# 0    18         8        307.0      130.0   3504         12.0         70
# 1    15         8        350.0      165.0   3693         11.5         70
# 2    18         8        318.0      150.0   3436         11.0         70
# 3    16         8        304.0      150.0   3433         12.0         70
# 4    17         8        302.0      140.0   3449         10.5         70
# ..   ..       ...          ...        ...    ...          ...        ...
# 393  27         4        140.0       86.0   2790         15.6         82
# 394  44         4         97.0       52.0   2130         24.6         82
# 395  32         4        135.0       84.0   2295         11.6         82
# 396  28         4        120.0       79.0   2625         18.6         82
# 397  31         4        119.0       82.0   2720         19.4         82
#
#      origin                       name
# 0       usa  chevrolet chevelle malibu
# ...

# %%
-> filling with one particular value
# Out:
#   File "C:\Users\gn221m\AppData\Local\Temp\ipykernel_8396\2853037583.py", line 1
#     -> filling with one particular value
#      ^
# SyntaxError: invalid syntax

# %%
df.fillna(30)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0     18          8         307.0       130.0    3504          12.0
# 1     15          8         350.0       165.0    3693          11.5
# 2     18          8         318.0       150.0    3436          11.0
# 3     16          8         304.0       150.0    3433          12.0
# 4     17          8         302.0       140.0    3449          10.5
# ..   ...        ...           ...         ...     ...           ...
# 393   27          4         140.0        86.0    2790          15.6
# 394   44          4          97.0        52.0    2130          24.6
# 395   32          4         135.0        84.0    2295          11.6
# 396   28          4         120.0        79.0    2625          18.6
# 397   31          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df['horsepower'].mean()
# Out:
# 104.46938775510205

# %%
mean_df = round(df['horsepower'].mean(),2)

# %%
df.fillna(mean_df)
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0     18          8         307.0       130.0    3504          12.0
# 1     15          8         350.0       165.0    3693          11.5
# 2     18          8         318.0       150.0    3436          11.0
# 3     16          8         304.0       150.0    3433          12.0
# 4     17          8         302.0       140.0    3449          10.5
# ..   ...        ...           ...         ...     ...           ...
# 393   27          4         140.0        86.0    2790          15.6
# 394   44          4          97.0        52.0    2130          24.6
# 395   32          4         135.0        84.0    2295          11.6
# 396   28          4         120.0        79.0    2625          18.6
# 397   31          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df[df['horsepower'].isnull()]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32    25          4          98.0         NaN    2046          19.0
# 126   21          6         200.0         NaN    2875          17.0
# 330   40          4          85.0         NaN    1835          17.3
# 336   23          4         140.0         NaN    2905          14.3
# 354   34          4         100.0         NaN    2320          15.8
# 374   23          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name
# 32           71     usa            ford pinto
# 126          74     usa         ford maverick
# 330          80  europe  renault lecar deluxe
# 336          80     usa    ford mustang cobra
# 354          81  europe           renault 18i
# 374          82     usa        amc concord dl

# %%
median_df = round(df['horsepower'].median(),2)
df.fillna(median_df)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
df_ma = df.fillna(max(df['horsepower']))

# %%
df_ma[df_ma['horsepower'].isnull()]
# Out:
# Empty DataFrame
# Columns: [mpg, cylinders, displacement, horsepower, weight, acceleration, model_year, origin, name]
# Index: []

# %%
df_ma.isna().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df_ma.isnull().sum()
# Out:
# mpg             0
# cylinders       0
# displacement    0
# horsepower      0
# weight          0
# acceleration    0
# model_year      0
# origin          0
# name            0
# dtype: int64

# %%
df.fillna(min(df['horsepower']))
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
mean_df = round(df['horsepower'].mean(),2)
df['horsepower_new'] = df['horsepower'].fillna(mean_df)

# %%
df.head(2)
# Out:
#    mpg  cylinders  displacement  horsepower  weight  acceleration  model_year  \
# 0   18          8         307.0       130.0    3504          12.0          70
# 1   15          8         350.0       165.0    3693          11.5          70
#
#   origin                       name  horsepower_new
# 0    usa  chevrolet chevelle malibu           130.0
# 1    usa          buick skylark 320           165.0

# %%
df[df['horsepower'].isnull()]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 32    25          4          98.0         NaN    2046          19.0
# 126   21          6         200.0         NaN    2875          17.0
# 330   40          4          85.0         NaN    1835          17.3
# 336   23          4         140.0         NaN    2905          14.3
# 354   34          4         100.0         NaN    2320          15.8
# 374   23          4         151.0         NaN    3035          20.5
#
#      model_year  origin                  name  horsepower_new
# 32           71     usa            ford pinto          104.47
# 126          74     usa         ford maverick          104.47
# 330          80  europe  renault lecar deluxe          104.47
# 336          80     usa    ford mustang cobra          104.47
# 354          81  europe           renault 18i          104.47
# 374          82     usa        amc concord dl          104.47

# %%
df = df.rename(columns={'horsepower':'horsepower_old'})

# %%
df.head(2)
# Out:
#    mpg  cylinders  displacement  horsepower_old  weight  acceleration  \
# 0   18          8         307.0           130.0    3504          12.0
# 1   15          8         350.0           165.0    3693          11.5
#
#    model_year origin                       name  horsepower_new
# 0          70    usa  chevrolet chevelle malibu           130.0
# 1          70    usa          buick skylark 320           165.0

# %%
df.isnull().sum()
# Out:
# mpg               0
# cylinders         0
# displacement      0
# horsepower_old    6
# weight            0
# acceleration      0
# model_year        0
# origin            0
# name              0
# horsepower_new    0
# dtype: int64

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({"key":["k0","k1","k2","k3"],
                   "A": ["A0","A1","A2","A3"],
                   "B": ["B0","B1","B2","B3"]
                   })

# %%
df1
# Out:
#   key   A   B
# 0  k0  A0  B0
# 1  k1  A1  B1
# 2  k2  A2  B2
# 3  k3  A3  B3

# %%
df2 = pd.DataFrame({"key":["k0","k1","k5","k6"],
                   "D": ["D0","D1","D2","D3"],
                   "E": ["E0","E1","E2","E3"]
                   })

# %%
df2
# Out:
#   key   D   E
# 0  k0  D0  E0
# 1  k1  D1  E1
# 2  k5  D2  E2
# 3  k6  D3  E3

# %%
df_inner = pd.merge(df1,df2,on=['key'],how='inner')

# %%
df_inner
# Out:
#   key   A   B   D   E
# 0  k0  A0  B0  D0  E0
# 1  k1  A1  B1  D1  E1

# %%
df_left = pd.merge(df1,df2,on='key',how='left',indicator=True)

# %%
df_left
# Out:
#   key   A   B    D    E     _merge
# 0  k0  A0  B0   D0   E0       both
# 1  k1  A1  B1   D1   E1       both
# 2  k2  A2  B2  NaN  NaN  left_only
# 3  k3  A3  B3  NaN  NaN  left_only

# %%
df_right = pd.merge(df1,df2,on='key',how='right')

# %%
df_right
# Out:
#   key    A    B   D   E
# 0  k0   A0   B0  D0  E0
# 1  k1   A1   B1  D1  E1
# 2  k5  NaN  NaN  D2  E2
# 3  k6  NaN  NaN  D3  E3

# %%
df_outer = pd.merge(df1,df2,on='key',how='outer')

# %%
df_outer
# Out:
#   key    A    B    D    E
# 0  k0   A0   B0   D0   E0
# 1  k1   A1   B1   D1   E1
# 2  k2   A2   B2  NaN  NaN
# 3  k3   A3   B3  NaN  NaN
# 4  k5  NaN  NaN   D2   E2
# 5  k6  NaN  NaN   D3   E3

# %%
df_cross = pd.merge(df1,df2,how='cross')

# %%
df1.shape
# Out:
# (4, 3)

# %%
df2.shape
# Out:
# (4, 3)

# %%
df_cross
# Out:
#    key_x   A   B key_y   D   E
# 0     k0  A0  B0    k0  D0  E0
# 1     k0  A0  B0    k1  D1  E1
# 2     k0  A0  B0    k5  D2  E2
# 3     k0  A0  B0    k6  D3  E3
# 4     k1  A1  B1    k0  D0  E0
# 5     k1  A1  B1    k1  D1  E1
# 6     k1  A1  B1    k5  D2  E2
# 7     k1  A1  B1    k6  D3  E3
# 8     k2  A2  B2    k0  D0  E0
# 9     k2  A2  B2    k1  D1  E1
# 10    k2  A2  B2    k5  D2  E2
# 11    k2  A2  B2    k6  D3  E3
# 12    k3  A3  B3    k0  D0  E0
# 13    k3  A3  B3    k1  D1  E1
# 14    k3  A3  B3    k5  D2  E2
# 15    k3  A3  B3    k6  D3  E3

# %%
df_cross.shape
# Out:
# (16, 6)

# %%
df_outer = pd.merge(df1,df2,on='key',how='outer',indicator=True)

# %%
df_outer
# Out:
#   key    A    B    D    E      _merge
# 0  k0   A0   B0   D0   E0        both
# 1  k1   A1   B1   D1   E1        both
# 2  k2   A2   B2  NaN  NaN   left_only
# 3  k3   A3   B3  NaN  NaN   left_only
# 4  k5  NaN  NaN   D2   E2  right_only
# 5  k6  NaN  NaN   D3   E3  right_only

# %%
df3 = pd.DataFrame({"key":["k0","k1","k5","k6"],
                   "A": ["A0","A1","A5","A6"], 
                   "D": ["D0","D1","D2","D3"],
                   "E": ["E0","E1","E2","E3"]
                   })

# %%
df3
# Out:
#   key   A   D   E
# 0  k0  A0  D0  E0
# 1  k1  A1  D1  E1
# 2  k5  A5  D2  E2
# 3  k6  A6  D3  E3

# %%
df1
# Out:
#   key   A   B
# 0  k0  A0  B0
# 1  k1  A1  B1
# 2  k2  A2  B2
# 3  k3  A3  B3

# %%
# key,A  -- common columns

# %%
df_outer = pd.merge(df1,df3,on='key',how='outer',suffixes=('', '_y'),indicator=True)

# %%
df_outer
# Out:
#   key    A    B  A_y    D    E      _merge
# 0  k0   A0   B0   A0   D0   E0        both
# 1  k1   A1   B1   A1   D1   E1        both
# 2  k2   A2   B2  NaN  NaN  NaN   left_only
# 3  k3   A3   B3  NaN  NaN  NaN   left_only
# 4  k5  NaN  NaN   A5   D2   E2  right_only
# 5  k6  NaN  NaN   A6   D3   E3  right_only

# %% [markdown]
# ## Group_By

# %%
import seaborn as sns

# %%
df = sns.load_dataset("mpg")

# %%
df.shape
# Out:
# (398, 9)

# %%
df.head(2)
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320

# %%
df = df.sort_values(by='model_year')

# %%
df.head()
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0   18.0          8         307.0       130.0    3504          12.0
# 28   9.0          8         304.0       193.0    4732          18.5
# 27  11.0          8         318.0       210.0    4382          13.5
# 26  10.0          8         307.0       200.0    4376          15.0
# 25  10.0          8         360.0       215.0    4615          14.0
#
#     model_year origin                       name
# 0           70    usa  chevrolet chevelle malibu
# 28          70    usa                   hi 1200d
# 27          70    usa                 dodge d200
# 26          70    usa                  chevy c20
# 25          70    usa                  ford f250

# %%
df1 = df.sort_values(by='model_year',ascending=False)

# %%
df1.head(5)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 397  31.0          4         119.0        82.0    2720          19.4
# 380  36.0          4         120.0        88.0    2160          14.5
# 387  38.0          6         262.0        85.0    3015          17.0
# 384  32.0          4          91.0        67.0    1965          15.7
# 385  38.0          4          91.0        67.0    1995          16.2
#
#      model_year origin                               name
# 397          82    usa                         chevy s-10
# 380          82  japan                   nissan stanza xe
# 387          82    usa  oldsmobile cutlass ciera (diesel)
# 384          82  japan                 honda civic (auto)
# 385          82  japan                      datsun 310 gx

# %%
df['origin'].value_counts()
# Out:
# usa       249
# japan      79
# europe     70
# Name: origin, dtype: int64

# %%
### based on single 
df.groupby('origin')

# %%
df_g
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-48-cb0cf9eb3e4c> in <module>
# ----> 1 df_g
#
# NameError: name 'df_g' is not defined

# %%
df.groupby('origin').sum()
# Out:
#            mpg  cylinders  displacement  horsepower  weight  acceleration  \
# origin
# europe  1952.4        291        7640.0      5478.0  169631        1175.1
# japan   2405.6        324        8114.0      6307.0  175477        1277.6
# usa     5000.8       1556       61229.5     29167.0  837121        3743.4
#
#         model_year
# origin
# europe        5307
# japan         6118
# usa          18827

# %%
da = df.groupby('origin').mean()

# %%
da.head(2)
# Out:
#               mpg  cylinders  displacement  horsepower       weight  \
# origin
# europe  27.891429   4.157143    109.142857   80.558824  2423.300000
# japan   30.450633   4.101266    102.708861   79.835443  2221.227848
#
#         acceleration  model_year
# origin
# europe     16.787143   75.814286
# japan      16.172152   77.443038

# %%
da.reset_index(inplace=True)

# %%
da.head()
# Out:
#    origin        mpg  cylinders  displacement  horsepower       weight  \
# 0  europe  27.891429   4.157143    109.142857   80.558824  2423.300000
# 1   japan  30.450633   4.101266    102.708861   79.835443  2221.227848
# 2     usa  20.083534   6.248996    245.901606  119.048980  3361.931727
#
#    acceleration  model_year
# 0     16.787143   75.814286
# 1     16.172152   77.443038
# 2     15.033735   75.610442

# %%
da
# Out:
#    origin        mpg  cylinders  displacement  horsepower       weight  \
# 0  europe  27.891429   4.157143    109.142857   80.558824  2423.300000
# 1   japan  30.450633   4.101266    102.708861   79.835443  2221.227848
# 2     usa  20.083534   6.248996    245.901606  119.048980  3361.931727
#
#    acceleration  model_year
# 0     16.787143   75.814286
# 1     16.172152   77.443038
# 2     15.033735   75.610442

# %%
df.groupby(['origin','model_year'])

# %%
da = df.groupby(['origin','model_year']).sum()

# %%
da.shape
# Out:
# (39, 6)

# %%
da.head(2)
# Out:
#                      mpg  cylinders  displacement  horsepower  weight  \
# origin model_year
# europe 70          126.0         20         539.0       431.0   11546
#        71          115.0         16         380.0       296.0    8096
#
#                    acceleration
# origin model_year
# europe 70                  82.5
#        71                  67.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
da_merge = df.groupby(['origin','model_year'])['name'].apply(', '.join).reset_index()

# %%
da_merge.head(2)
# Out:
#    origin  model_year                                               name
# 0  europe          70  bmw 2002, saab 99e, audi 100 ls, volkswagen 11...
# 1  europe          71  peugeot 304, volkswagen model 111, opel 1900, ...

# %%
da_merge
# Out:
#     origin  model_year                                               name
# 0   europe          70  bmw 2002, saab 99e, audi 100 ls, volkswagen 11...
# 1   europe          71  peugeot 304, volkswagen model 111, opel 1900, ...
# 2   europe          72  volvo 145e (sw), volkswagen 411 (sw), peugeot ...
# 3   europe          73  fiat 124 sport coupe, saab 99le, fiat 128, ope...
# 4   europe          74  audi fox, volkswagen dasher, opel manta, fiat ...
# 5   europe          75  volkswagen dasher, audi 100ls, peugeot 504, vo...
# 6   europe          76  volkswagen rabbit, volvo 245, peugeot 504, mer...
# 7   europe          77  volkswagen rabbit custom, volkswagen dasher, b...
# 8   europe          78  volkswagen scirocco, audi 5000, volvo 264gl, s...
# 9   europe          79  mercedes benz 300d, peugeot 504, fiat strada c...
# 10  europe          80  vw dasher (diesel), audi 5000s (diesel), merce...
# 11  europe          81  peugeot 505s turbo diesel, renault 18i, volvo ...
# ...

# %%
da_merge.to_csv("merged.csv")

# %%
da.reset_index(inplace=True)

# %%
da.shape
# Out:
# (39, 8)

# %%
df = sns.load_dataset("titanic")

# %%
df.shape
# Out:
# (891, 15)

# %%
df.head(3)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True

# %%
df.tail(2)
# Out:
#      survived  pclass   sex   age  sibsp  parch   fare embarked  class  who  \
# 889         1       1  male  26.0      0      0  30.00        C  First  man
# 890         0       3  male  32.0      0      0   7.75        Q  Third  man
#
#      adult_male deck embark_town alive  alone
# 889        True    C   Cherbourg   yes   True
# 890        True  NaN  Queenstown    no   True

# %%
df1 = df.set_index('sex')

# %%
df1.shape
# Out:
# (891, 14)

# %%
df1.head(5)
# Out:
#         survived  pclass   age  sibsp  parch     fare embarked  class    who  \
# sex
# male           0       3  22.0      1      0   7.2500        S  Third    man
# female         1       1  38.0      1      0  71.2833        C  First  woman
# female         1       3  26.0      0      0   7.9250        S  Third  woman
# female         1       1  35.0      1      0  53.1000        S  First  woman
# male           0       3  35.0      0      0   8.0500        S  Third    man
#
#         adult_male deck  embark_town alive  alone
# sex
# male          True  NaN  Southampton    no  False
# female       False    C    Cherbourg   yes  False
# female       False  NaN  Southampton   yes   True
# female       False    C  Southampton   yes  False
# male          True  NaN  Southampton    no   True

# %%
df1.reset_index(inplace=True)

# %%
df1.head(2)
# Out:
#       sex  survived  pclass   age  sibsp  parch     fare embarked  class  \
# 0    male         0       3  22.0      1      0   7.2500        S  Third
# 1  female         1       1  38.0      1      0  71.2833        C  First
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
