# %% [markdown]
# # Lists
#
# Earlier when discussing strings we introduced the concept of a *sequence* in Python. Lists can be thought of the most general version of a *sequence* in Python. Unlike strings, they are mutable, meaning the elements inside a list can be changed!
#
# In this section we will learn about:
#
#     1.) Creating lists
#     2.) Indexing and Slicing Lists
#     3.) Basic List Methods
#     4). Mutability
#     4.) Nesting Lists
#     5.) Introduction to List Comprehensions
#
# Lists are constructed with brackets [] and commas separating each and every element in the list.
#
# Let's go ahead and see how we can construct lists!

# %%
empty_list = []

# %%
empty_list
# Out:
# []

# %%
type(empty_list)
# Out:
# list

# %%
# Assign a list to an variable named my_list
my_list = [1,2,3]

# %%
my_list
# Out:
# [1, 2, 3]

# %%
len(my_list)
# Out:
# 3

# %% [markdown]
# We just created a list of integers, but lists can actually hold different object types. For example:

# %%
my_list = ['A string',23,100.232,'o','@']

# %%
my_list
# Out:
# ['A string', 23, 100.232, 'o', '@']

# %% [markdown]
# Just like strings, the len() function will tell you how many items are in the sequence of the list.

# %%
len(my_list)
# Out:
# 5

# %% [markdown]
# ### Indexing and Slicing
# Indexing and slicing work just like in strings. Let's make a new list to remind ourselves of how this works:

# %%
sTR_1 = "hELLO WORLD"
        01234

# %%
my_list = ['one','two','three',4,5]
#            0       1     2   3  4
                      1:3

# %%
# Grab element at index 0
my_list[2]
# Out:
# 'three'

# %%
# Grab index 2 and everything past it   ---
my_list[2:]
# Out:
# ['three', 4, 5]

# %%
# Grab everything UP TO index 3
my_list[:3]
# Out:
# ['one', 'two', 'three']

# %%
# Grab everything 1st to UP TO index 3
my_list[2:4]    #--- IT WEILL GIVE OUPUT WITH INDEX 2,3
# Out:
# ['three', 4]

# %% [markdown]
# We can also use + to concatenate lists, just like we did for strings.

# %%
my_list_upd = my_list + ['new item']

# %% [markdown]
# Note: This doesn't actually change the original list!

# %%
my_list
# Out:
# ['one', 'two', 'three', 4, 5]

# %%
my_list_upd
# Out:
# ['one', 'two', 'three', 4, 5, 'new item']

# %% [markdown]
# You would have to reassign the list to make the change permanent.

# %%
# Reassign
my_list_upd = my_list + ['add new item permanently']

# %%
my_list_upd
# Out:
# ['one', 'two', 'three', 4, 5, 'add new item permanently']

# %%
my_list
# Out:
# ['one', 'two', 'three', 4, 5]

# %% [markdown]
# We can also use the * for a duplication method similar to strings:

# %%
# Make the list double
my_list * 2
# Out:
# ['one', 'two', 'three', 4, 5, 'one', 'two', 'three', 4, 5]

# %%
# Again doubling not permanent
my_list
# Out:
# ['one', 'two', 'three', 4, 5, 'add new item permanently']

# %% [markdown]
# ## Basic List Methods
#
# If you are familiar with another programming language, you might start to draw parallels between arrays in another language and lists in Python. Lists in Python however, tend to be more flexible than arrays in other languages for a two good reasons: they have no fixed size (meaning we don't have to specify how big a list will be), and they have no fixed type constraint (like we've seen above).
#
# Let's go ahead and explore some more special methods for lists:

# %%
# Create a new list
list1 = [1,2,3]

# %% [markdown]
# Use the **append** method to permanently add an item to the end of a list:

# %%
# Append
list1.append('append me!')

# %%
# Show
list1
# Out:
# [1, 2, 3, 'append me!']

# %%
list1
# Out:
# [1, 2, 3, 'append me!']

# %%
list1[0]= 'change'

# %%
list1
# Out:
# ['change', 2, 3, 'append me!']

# %% [markdown]
# Use **pop** to "pop off" an item from the list. By default pop takes off the last index, but you can also specify which index to pop off. Let's see an example:

# %%
# Pop off the 0 indexed item
list_new = list1.pop()

# %%
list_new
# Out:
# 3

# %%
# Show
list1
# Out:
# ['change', 2]

# %%
# Assign the popped element, remember default popped index is -1
popped_item = list1.pop()

# %%
popped_item
# Out:
# 'append me!'

# %%
# Show remaining list
list1
# Out:
# [1, 2]

# %% [markdown]
# It should also be noted that lists indexing will return an error if there is no element at that index. For example:

# %%
list1[10]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-1a2e5d318e75> in <module>
# ----> 1 list1[10]
#
# IndexError: list index out of range

# %% [markdown]
# We can use the **sort** method and the **reverse** methods to also effect your lists:

# %%
# Question is: Write a python function to sort the elements from the list of elements

new_list = ['a','e','x','b','c']

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
#Show
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
# Use reverse to reverse order (this is permanent!)
new_list.reverse()

# %%
new_list
# Out:
# ['c', 'b', 'x', 'e', 'a']

# %%
# Use sort to sort the list (in this case alphabetical order, but for numbers it will go ascending)
new_list.sort()

# %%
new_list
# Out:
# ['a', 'b', 'c', 'e', 'x']

# %%
### Assignment
# Question is: Write a python function to sort the elements from the list of elements without using sort method


input_list = = ['a','e','x','b','c']

# output i am expecting ['a', 'b', 'c', 'e', 'x']

# %% [markdown]
# ## Nesting Lists
# A great feature of of Python data structures is that they support *nesting*. This means we can have data structures within data structures. For example: A list inside a list.
#
# Let's see how this works!

# %%
# Let's make three lists
       #oc 1stcol 2nd col
       #0,0 0,1 0,2
lst_1=[1,2,3]# -- oth row
lst_2=[4,5,6] #-- 1st row
lst_3=[7,8,9] #-- 2nd row

# Make a list of lists to form a matrix
matrix = [lst_1,lst_2,lst_3]

# %%
matrix = [1,2,3
          4,5,6
          7,8,9]

# %%
print(matrix)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[0]
# Out:
# [1, 2, 3]

# %%
matrix[0][1]
# Out:
# 2

# %%
type(matrix)
# Out:
# list

# %%
# Show
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# We can again use indexing to grab elements, but now there are two levels for the index. The items in the matrix object, and then the items inside that list!

# %%
# Grab first item in matrix object
matrix[0]
# Out:
# [1, 2, 3]

# %%
matrix[1]
# Out:
# [4, 5, 6]

# %%
matrix[2]
# Out:
# [7, 8, 9]

# %%
# Grab first item of the first item in the matrix object
matrix[0][0]
# Out:
# 1

# %%
matrix[0][1]
# Out:
# 2

# %%
# Show
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
matrix[1][0]

# %%
matrix[2][1]
# Out:
# 8

# %% [markdown]
# # List Comprehensions
# Python has an advanced feature called list comprehensions. They allow for quick construction of lists. To fully understand list comprehensions we need to understand for loops. So don't worry if you don't completely understand this section, and feel free to just skip it since we will return to this topic later.
#
# But in case you want to know now, here are a few examples!

# %%
matrix
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
# Build a list comprehension by deconstructing a for loop within a []
first_col = [row[0] for row in matrix]

# %%
first_col
# Out:
# [1, 4, 7]

# %% [markdown]
# We used a list comprehension here to grab the first element of every row in the matrix object. We will cover this in much more detail later on!
#
# For more advanced methods and features of lists in Python, check out the Advanced Lists section later on in this course!
