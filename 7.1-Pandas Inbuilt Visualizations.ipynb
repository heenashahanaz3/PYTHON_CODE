# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sb

# %%
# %matplotlib inline

# %%
from numpy.random import randn

# %%
df = pd.DataFrame(abs(randn(1000,4)),columns='Sales Trasaction Units Gross_Profits'.split())

# %%
df.head()
# Out:
#       Sales  Trasaction     Units  Gross_Profits
# 0  0.186992    0.838616  2.393684       0.136441
# 1  1.405621    1.083060  0.621439       0.198374
# 2  1.078017    1.265098  0.224292       1.485721
# 3  0.763668    0.160204  1.324134       0.814190
# 4  2.304233    1.259002  0.598154       2.467102

# %%
df.describe()
# Out:
#              Sales   Trasaction        Units  Gross_Profits
# count  1000.000000  1000.000000  1000.000000    1000.000000
# mean      0.780094     0.819733     0.823594       0.808777
# std       0.595472     0.616056     0.621308       0.598544
# min       0.000805     0.001063     0.002194       0.000049
# 25%       0.311995     0.311398     0.336984       0.332025
# 50%       0.657364     0.690608     0.681535       0.684922
# 75%       1.113786     1.237457     1.187679       1.157092
# max       4.125335     3.718027     3.491656       3.463964

# %%
df['Sales'].hist()

# %%
df['Gross_Profits'].hist()

# %%
df['Sales'].plot(kind='hist',bins=20)

# %%
df['Sales'].plot.hist()

# %%
df.plot.area()

# %%
df.plot.bar()

# %%
df.plot.bar(stacked=True)

# %%
df.plot.hist(bins=30)

# %%
df.plot.scatter(x='Sales' , y='Units')

# %%
df.plot.scatter(x='Sales' , y='Units', c="Trasaction",cmap='coolwarm')

# %%
df.plot.scatter(x='Sales' , y='Units', s=df["Trasaction"]*100)

# %%
df.plot.box()
